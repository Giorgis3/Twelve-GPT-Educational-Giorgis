# %% [markdown]
# # Kernel Smoke Test
# Run the cells below. If both show output quickly, notebook execution is healthy.

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Pedro\Desktop\Portfolio\12 Football CE - CB Pairing AI Analyst\Twelve-GPT-Educational-Giorgis\.venv\Scripts\python.exe

# %%
import numpy as np
print('numpy', np.__version__)
print('ok')
# Out:
# numpy 1.26.4
# ok
